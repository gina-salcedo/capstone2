# %% [markdown]
# # Drinking Age Data Set

# %% [markdown]
# #### Loaded mental health data 2014 and 2016 into two separate dataframes

# %%
import pandas as pd
import numpy as np

math = pd.read_csv('student-math.csv')
port = pd.read_csv('student-portuguese.csv')

# %%
print(math.count())
print(port.count())
# Out:
# school        395
# sex           395
# age           395
# address       395
# famsize       395
# Pstatus       395
# Medu          395
# Fedu          395
# Mjob          395
# Fjob          395
# reason        395
# guardian      395
# traveltime    395
# studytime     395
# failures      395
# schoolsup     395
# famsup        395
# paid          395
# activities    395
# nursery       395
# higher        395
# internet      395
# romantic      395
# famrel        395
# freetime      395
# goout         395
# Dalc          395
# Walc          395
# health        395
# absences      395
# G1            395
# G2            395
# G3            395
# dtype: int64
# school        649
# sex           649
# age           649
# address       649
# famsize       649
# Pstatus       649
# Medu          649
# Fedu          649
# Mjob          649
# Fjob          649
# reason        649
# guardian      649
# traveltime    649
# studytime     649
# failures      649
# schoolsup     649
# famsup        649
# paid          649
# activities    649
# nursery       649
# higher        649
# internet      649
# romantic      649
# famrel        649
# freetime      649
# goout         649
# Dalc          649
# Walc          649
# health        649
# absences      649
# G1            649
# G2            649
# G3            649
# dtype: int64

# %%
#checking unique answers for drinking levels questions

print(math['Dalc'].unique())
print(math['Walc'].unique())
print(port['Dalc'].unique())
print(port['Walc'].unique())
# Out:
# [1 2 5 3 4]
# [1 3 2 4 5]
# [1 2 5 3 4]
# [1 3 2 4 5]

# %% [markdown]
# #### The data is from a hypothethical (read: I made it up) survey asking how much each subject would pay for a meal. Each participant was given some information about the restaurant and asked a few questions about him/herself. Participants were asked about one restaurant each, so unfortunately, you won't be able to control by participant.

# %% [markdown]
# #### This does mean you can join the two dataframes into a single one! Try doing this using the pandas merge function.

# %%
print(list(df_rr.columns.values))
print(list(df_ui.columns.values))
# Out:
# ['Reviewer', 'Cuisine', 'HasSetMenu', 'YelpStars', 'SellsCoffee', 'SellsBeer', 'SellsWine', 'SellsSpirits', 'Price']
# ['ID', 'Age', 'Gender', 'Height', 'Weight', 'WearsGlasses', 'Home', 'Salary', 'DrinksCoffee', 'DrinksBeer', 'DrinksWine', 'DrinksSpirits', 'IsVegan', 'IsVegetarian']

# %%
#ME

df = df_ui.merge(df_rr, left_on='ID', right_on='Reviewer', how='left').drop('Reviewer', axis=1)
df.set_index('ID', inplace=True)

#to view all columns:
pd.set_option('display.max_columns', len(df.columns)+1)
df.head()
# Out:
#     Age  Gender  Height  Weight WearsGlasses      Home  Salary  DrinksCoffee  \
# ID
# 1    15    male     175      77          yes  suburban       3             1
# 2    49  female     171      75           no     rural       0             0
# 3    63  female     147      55           no  suburban       1             1
# 4    75    male     170      82           no     rural       3             1
# 5    46  female     159      64          yes  suburban       1             0
#
#     DrinksBeer  DrinksWine  DrinksSpirits  IsVegan  IsVegetarian  Cuisine  \
# ID
# 1            1           2              0        0             0   French
# 2            0           1              1        0             0   Indian
# 3            0           0              0        0             0   Indian
# 4            0           0              0        0             0  Italian
# 5            1           0              1        0             0   French
#
#    HasSetMenu  YelpStars  SellsCoffee  SellsBeer  SellsWine  SellsSpirits  \
# ID
# 1          no        2.5            1          1          1             1
# 2          no        1.0            1          2          2             1
# 3          no        3.5            1          1          0             1
# 4          no        0.5            0          0          1             1
# 5         yes        2.0            2          1          1             1
#
#     Price
# ID
# 1      50
# 2      12
# 3      47
# 4      23
# 5      36

# %%
#IN CLASS

df2=df.drop(['WearsGlasses', 'IsVegan', 'IsVegetarian', 'Height', 'Weight', 'Gender'], axis=1) #also got rid of reviewer

# %% [markdown]
# #### At this point, your data is now unified in a single dataframe. However, you will be unable to regress over many of these variables. Add dummy variables where appropriate. Feel free to ignore any columns which you feel are obviously superfluous.

# %%
#ME: df=df.join(pd.get_dummies(df['Home'], drop_first=True))
#Class:
#df3=df2.join(pd.get_dummies(df2[['Home', 'Salary', 'DrinksCoffee','Cuisine','HasSetMenu']], 
#                            prefix=['Home', 'Salary', 'DrinksCoffee', 'Cuisine', 'HasSetMenu'],
#                            drop_first=True)
#SEE CLASS CODE FOR BETTER DUMMY VARIABLE THING
#df['is_male'] = df['Gender'].apply(lambda x: 1 if x == 'male' else 0)

# %%
#Do we need to check whether price is normally distributed?
## No, though it gives the regression some nice properties,the regression will still work

# %% [markdown]
# Huber and Ransak: Robust regressions that lessen the impact of outliers because they are not minimizing the square error
#
# Lasso penalizes the absolute value of the terms
#
# Ridge penalizes the weights with the square of their size, rather than the absolute value, but it makes them smaller, not zero (unlike Lasso)

# %%
df2.head()
# Out:
#     Age      Home  Salary  DrinksCoffee  DrinksBeer  DrinksWine  \
# ID
# 1    15  suburban       3             1           1           2
# 2    49     rural       0             0           0           1
# 3    63  suburban       1             1           0           0
# 4    75     rural       3             1           0           0
# 5    46  suburban       1             0           1           0
#
#     DrinksSpirits  Cuisine HasSetMenu  YelpStars  SellsCoffee  SellsBeer  \
# ID
# 1               0   French         no        2.5            1          1
# 2               1   Indian         no        1.0            1          2
# 3               0   Indian         no        3.5            1          1
# 4               0  Italian         no        0.5            0          0
# 5               1   French        yes        2.0            2          1
#
#     SellsWine  SellsSpirits  Price
# ID
# 1           1             1     50
# 2           2             1     12
# 3           0             1     47
# 4           1             1     23
# 5           1             1     36

# %%
df.join(pd.get_dummies(df['Cuisine'], drop_first=True)).head #This will create dummies AND leave the old variable in

df4= pd.get_dummies(df['HasSetMenu'], drop_first=True).head #This will create dummies AND leave the old variable in

df4.head()


#For LASSO, you typically want to use the log scale for the penalties
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-c40f14f24999> in <module>()
#       3 df4= pd.get_dummies(df['HasSetMenu'], drop_first=True).head #This will create dummies AND leave the old variable in
#       4
# ----> 5 df4.head()
#       6
#
# AttributeError: 'function' object has no attribute 'head'

# %%
df.head()
# Out:
#     Age  Gender  Height  Weight WearsGlasses      Home  Salary  DrinksCoffee  \
# ID
# 1    15    male     175      77          yes  suburban       3             1
# 2    49  female     171      75           no     rural       0             0
# 3    63  female     147      55           no  suburban       1             1
# 4    75    male     170      82           no     rural       3             1
# 5    46  female     159      64          yes  suburban       1             0
#
#     DrinksBeer  DrinksWine  DrinksSpirits   ...     Cuisine  HasSetMenu  \
# ID                                          ...
# 1            1           2              0   ...      French          no
# 2            0           1              1   ...      Indian          no
# 3            0           0              0   ...      Indian          no
# 4            0           0              0   ...     Italian          no
# 5            1           0              1   ...      French         yes
#
#    YelpStars SellsCoffee  SellsBeer  SellsWine  SellsSpirits  Price  suburban  \
# ID
# 1        2.5           1          1          1             1     50         1
# 2        1.0           1          2          2             1     12         0
# 3        3.5           1          1          0             1     47         1
# 4        0.5           0          0          1             1     23         0
# 5        2.0           2          1          1             1     36         1
#
#     urban  is_male
# ID
# 1       0        1
# 2       0        0
# 3       0        0
# 4       0        1
# 5       0        0
#
# [5 rows x 24 columns]

# %%
df['SetMenu']= df['HasSetMenu'].apply(lambda x: 1 if x == 'yes' else 0)

# %%
df.drop(['Height', 'WearsGlasses', 'Home', 'Gender', 'HasSetMenu'], axis=1, inplace=True)
df.head()
# Out:
#     Age  Weight  Salary  DrinksCoffee  DrinksBeer  DrinksWine  DrinksSpirits  \
# ID
# 1    15      77       3             1           1           2              0
# 2    49      75       0             0           0           1              1
# 3    63      55       1             1           0           0              0
# 4    75      82       3             1           0           0              0
# 5    46      64       1             0           1           0              1
#
#     IsVegan  IsVegetarian  Cuisine  YelpStars  SellsCoffee  SellsBeer  \
# ID
# 1         0             0   French        2.5            1          1
# 2         0             0   Indian        1.0            1          2
# 3         0             0   Indian        3.5            1          1
# 4         0             0  Italian        0.5            0          0
# 5         0             0   French        2.0            2          1
#
#     SellsWine  SellsSpirits  Price  suburban  urban  is_male  SetMenu
# ID
# 1           1             1     50         1      0        1        0
# 2           2             1     12         0      0        0        0
# 3           0             1     47         1      0        0        0
# 4           1             1     23         0      0        1        0
# 5           1             1     36         1      0        0        1

# %%
df['Cuisine'].unique()
# Out:
# array(['French', 'Indian', 'Italian', 'American', 'Mexican'], dtype=object)

# %%
df=df.join(pd.get_dummies(df['Cuisine'], drop_first=True))

# %%
df.head()
# Out:
#     Age  Weight  Salary  DrinksCoffee  DrinksBeer  DrinksWine  DrinksSpirits  \
# ID
# 1    15      77       3             1           1           2              0
# 2    49      75       0             0           0           1              1
# 3    63      55       1             1           0           0              0
# 4    75      82       3             1           0           0              0
# 5    46      64       1             0           1           0              1
#
#     IsVegan  IsVegetarian  Cuisine   ...     SellsSpirits  Price  suburban  \
# ID                                   ...
# 1         0             0   French   ...                1     50         1
# 2         0             0   Indian   ...                1     12         0
# 3         0             0   Indian   ...                1     47         1
# 4         0             0  Italian   ...                1     23         0
# 5         0             0   French   ...                1     36         1
#
#     urban  is_male  SetMenu  French  Indian  Italian  Mexican
# ID
# 1       0        1        0       1       0        0        0
# 2       0        0        0       0       1        0        0
# 3       0        0        0       0       1        0        0
# 4       0        1        0       0       0        1        0
# 5       0        0        1       1       0        0        0
#
# [5 rows x 24 columns]

# %%
df.drop(['Weight', 'Cuisine'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     Age  Salary  DrinksCoffee  DrinksBeer  DrinksWine  DrinksSpirits  IsVegan  \
# ID
# 1    15       3             1           1           2              0        0
# 2    49       0             0           0           1              1        0
# 3    63       1             1           0           0              0        0
# 4    75       3             1           0           0              0        0
# 5    46       1             0           1           0              1        0
#
#     IsVegetarian  YelpStars  SellsCoffee   ...     SellsSpirits  Price  \
# ID                                         ...
# 1              0        2.5            1   ...                1     50
# 2              0        1.0            1   ...                1     12
# 3              0        3.5            1   ...                1     47
# 4              0        0.5            0   ...                1     23
# 5              0        2.0            2   ...                1     36
#
#     suburban  urban  is_male  SetMenu  French  Indian  Italian  Mexican
# ID
# 1          1      0        1        0       1       0        0        0
# 2          0      0        0        0       0       1        0        0
# 3          1      0        0        0       0       1        0        0
# 4          0      0        1        0       0       0        1        0
# 5          1      0        0        1       1       0        0        0
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Using the tools you've used in class, try to predict the price an individual will be willing to pay for a given meal based on the characteristics of the restaurant and the individual.
#
# **Note:** This may require a bit of exploration. Don't worry if your results aren't perfect, but try to derive a model with some predictive power.

# %%
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
# %matplotlib notebook

age = df['Age'].corr(df['Price'], method='spearman')
print 'The Spearman Correlation is: '
print age

plt.scatter(df['Age'], df['Price'])
plt.ylabel('Age')
plt.xlabel('Price')
plt.title('Age vs Price')
# Out:
# The Spearman Correlation is:
# 0.0256950968989
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

# Wine drinking affect price?
df.groupby('DrinksWine')['Price'].hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# DrinksWine
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# 2    Axes(0.125,0.11;0.775x0.77)
# Name: Price, dtype: object

# %%
print(list(df.columns.values))
# Out:
# ['Age', 'Salary', 'DrinksCoffee', 'DrinksBeer', 'DrinksWine', 'DrinksSpirits', 'IsVegan', 'IsVegetarian', 'YelpStars', 'SellsCoffee', 'SellsBeer', 'SellsWine', 'SellsSpirits', 'Price', 'suburban', 'urban', 'is_male', 'SetMenu', 'French', 'Indian', 'Italian', 'Mexican']

# %%
from sklearn import linear_model
import sklearn.model_selection as ms
import sklearn.linear_model as lm

ARB_CONST = 172

from sklearn.model_selection import GridSearchCV

ARB_CONST = 172
train_x, test_x, train_y, test_y = ms.train_test_split(df, y, test_size=0.2, random_state=ARB_CONST) 

gs = GridSearchCV(estimator=lm.Ridge(),
                  cv=5, 
                  param_grid={'alpha': np.logspace(-10, 10, 21)},
                  scoring='neg_mean_squared_error')
gs.fit(train_x, train_y)

print(gs.best_params_)
print(gs.best_estimator_.coef_)
print(gs.best_estimator_.intercept_)
# Out:
# {'alpha': 1e-10}
# [  7.54903167e-17   3.40867092e-14   8.58273458e-15  -3.63652186e-15
#    1.52030839e-14  -4.65278329e-15   2.89137422e-15  -2.10899485e-15
#    1.77020701e-13   1.00632252e-14  -2.64461135e-15   1.91635683e-14
#   -1.74936111e-16   1.00000000e+00  -5.78300773e-15  -7.15907992e-15
#   -1.06318489e-15   1.26929684e-14   1.72614475e-13   5.49759133e-14
#    1.07563581e-13   4.86430121e-14]
# -1.56319401867e-13

# %%
df=df.join(pd.get_dummies(df['DrinksWine'], drop_first=True))

# %%
df.head()
# Out:
#     Age  Salary  DrinksCoffee  DrinksBeer  DrinksWine  DrinksSpirits  IsVegan  \
# ID
# 1    15       3             1           1           2              0        0
# 2    49       0             0           0           1              1        0
# 3    63       1             1           0           0              0        0
# 4    75       3             1           0           0              0        0
# 5    46       1             0           1           0              1        0
#
#     IsVegetarian  YelpStars  SellsCoffee ...  suburban  urban  is_male  \
# ID                                       ...
# 1              0        2.5            1 ...         1      0        1
# 2              0        1.0            1 ...         0      0        0
# 3              0        3.5            1 ...         1      0        0
# 4              0        0.5            0 ...         0      0        1
# 5              0        2.0            2 ...         1      0        0
#
#     SetMenu  French  Indian  Italian  Mexican  1  2
# ID
# 1         0       1       0        0        0  0  1
# 2         0       0       1        0        0  1  0
# 3         0       0       1        0        0  0  0
# 4         0       0       0        1        0  0  0
# 5         1       1       0        0        0  0  0
#
# [5 rows x 24 columns]

# %%
import sklearn.linear_model as lm
import numpy as np

lin = lm.LinearRegression()
huber = lm.HuberRegressor()
ransac = lm.RANSACRegressor()

# %%
print(list(df.columns.values))
# Out:
# ['Age', 'Salary', 'DrinksCoffee', 'DrinksBeer', 'DrinksWine', 'DrinksSpirits', 'IsVegan', 'IsVegetarian', 'YelpStars', 'SellsCoffee', 'SellsBeer', 'SellsWine', 'SellsSpirits', 'Price', 'suburban', 'urban', 'is_male', 'SetMenu', 'French', 'Indian', 'Italian', 'Mexican', 1L, 2L]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

for model in [lin, huber, ransac]:
    model.fit(df['Age'].values[:, np.newaxis], df['Price'])

xrng = np.arange(df['Age'].min(), df['Age'].max(), .01)[:, np.newaxis]
plt.plot(df['Age'], df['Price'], '.b')
plt.plot(xrng, lin.predict(xrng), '--r', label='linear')
plt.plot(xrng, huber.predict(xrng), '--g', label='huber')
plt.plot(xrng, ransac.predict(xrng), '--k', label='ransac')
plt.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

for model in [lin, huber, ransac]:
    model.fit(df['YelpStars'].values[:, np.newaxis], df['Price'])

xrng = np.arange(df['YelpStars'].min(), df['YelpStars'].max(), .01)[:, np.newaxis]
plt.plot(df['YelpStars'], df['Price'], '.b')
plt.plot(xrng, lin.predict(xrng), '--r', label='linear')
plt.plot(xrng, huber.predict(xrng), '--g', label='huber')
plt.plot(xrng, ransac.predict(xrng), '--k', label='ransac')
plt.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Using a statistical test, demonstrate that your predicted values are better than random chance at guessing the correct price.

# %% [markdown]
# Answer here was to see if you're better than the average of your actual prices. Take the mean of each column
# Make that the model
# Then compare your error to the mean
# Test for that (high-level, review answers)
#
# If you think your errors are noraml you can do a paired T test
# OW you can do the sin rank
